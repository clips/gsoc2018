# %% [markdown]
# ### Testing pattern.web twitter functionality

# %% [markdown]
# #### Have to install:
#
# numpy, nltk, scipy, feedparser, bs4

# %%
import pattern
import time
pattern.__version__
# Out:
# '2.6'

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
from pattern.en import tag

# %%
from pattern.vector import KNN, count

# %%
from pattern.web import Twitter, plaintext
twitter = Twitter()

# %%
tweets = []
k = 1
for tweet in twitter.search('#MAGA', cached=False, count=10, start=1):
    print(k)
    print(plaintext(tweet.txt))
    print('\n')
    k += 1
    tweets.append(tweet)

# %%
for tweet in tweets:
    print(len(tweet.txt))

# %%
from pattern.web import Twitter
print(Twitter().trends(cached=False))

# %%
from pattern.web import Twitter

# %%
s = Twitter(throttle=0.5).stream('#MAGA')
texts = []
for i in range(10):
    time.sleep(1) 
    s.update(bytes=4024)  
    if s:
        texts.append(s[-1].text)
        print(s[-1].text)

# %% [markdown]
# ### Getting #MAGA tweets

# %%
from tqdm import tqdm_notebook
from pattern.web import Twitter

# %%
t = Twitter(throttle=0.7)
i = None
tweets = []
for j in tqdm_notebook(range(30)):
    for tweet in t.search('#MAGA', start=i, count=100):
        #print(tweet.text, '\n')
        tweets.append(tweet)
        i = tweet.id
        #print(i)
# Out:
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))

# %%
len(tweets)
# Out:
# 3000

# %%
# limit 150 requests per 15 min
def get_tweets(num_queries=150, cur_id=None, tweets_per_query=100):
    
    tweets = []
    t = Twitter(throttle=0.5)
    max_queries_per_period = 150
    start = time.time()
    period_time = 15 * 60 #seconds
    
    for j in tqdm_notebook(range(num_queries)):
        for tweet in t.search('#MAGA', start=cur_id, count=tweets_per_query):
            tweets.append(tweet)
            cur_id = tweet.id
        if j % max_queries_per_period == 0 and j > 0:
            print("sleeping for {} seconds".format(period_time - (time.time()-start)))
            time.sleep(period_time - (time.time()-start))
            start = time.time()
        print("Downloaded {} tweets".format(len(tweets)))
    return tweets

# %%
tweets = get_tweets()
# Out:
# HBox(children=(IntProgress(value=0, max=150), HTML(value='')))
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 400 tweets
# Downloaded 500 tweets
# Downloaded 600 tweets
# Downloaded 700 tweets
# Downloaded 800 tweets
# Downloaded 900 tweets
# Downloaded 1000 tweets
# Downloaded 1100 tweets
# Downloaded 1200 tweets
# Downloaded 1300 tweets
# Downloaded 1400 tweets
# Downloaded 1500 tweets
# Downloaded 1600 tweets
# Downloaded 1700 tweets
# Downloaded 1800 tweets
# Downloaded 1900 tweets
# Downloaded 2000 tweets
# Downloaded 2100 tweets
# Downloaded 2200 tweets
# Downloaded 2300 tweets
# Downloaded 2400 tweets
# Downloaded 2500 tweets
# Downloaded 2600 tweets
# Downloaded 2700 tweets
# Downloaded 2800 tweets
# Downloaded 2900 tweets
# Downloaded 3000 tweets
# Downloaded 3100 tweets
# Downloaded 3200 tweets
# Downloaded 3300 tweets
# Downloaded 3400 tweets
# Downloaded 3500 tweets
# Downloaded 3600 tweets
# Downloaded 3700 tweets
# Downloaded 3800 tweets
# Downloaded 3900 tweets
# Downloaded 4000 tweets
# Downloaded 4100 tweets
# Downloaded 4200 tweets
# Downloaded 4300 tweets
# Downloaded 4400 tweets
# Downloaded 4500 tweets
# Downloaded 4600 tweets
# Downloaded 4700 tweets
# Downloaded 4800 tweets
# Downloaded 4900 tweets
# Downloaded 5000 tweets
# Downloaded 5100 tweets
# Downloaded 5200 tweets
# Downloaded 5300 tweets
# Downloaded 5400 tweets
# Downloaded 5500 tweets
# Downloaded 5600 tweets
# Downloaded 5700 tweets
# Downloaded 5800 tweets
# Downloaded 5900 tweets
# Downloaded 6000 tweets
# Downloaded 6100 tweets
# Downloaded 6200 tweets
# Downloaded 6300 tweets
# Downloaded 6400 tweets
# Downloaded 6500 tweets
# Downloaded 6600 tweets
# Downloaded 6700 tweets
# Downloaded 6800 tweets
# Downloaded 6900 tweets
# Downloaded 7000 tweets
# Downloaded 7100 tweets
# Downloaded 7200 tweets
# Downloaded 7300 tweets
# Downloaded 7400 tweets
# Downloaded 7500 tweets
# Downloaded 7600 tweets
# Downloaded 7700 tweets
# Downloaded 7800 tweets
# Downloaded 7900 tweets
# Downloaded 8000 tweets
# Downloaded 8100 tweets
# Downloaded 8200 tweets
# Downloaded 8300 tweets
# Downloaded 8400 tweets
# Downloaded 8500 tweets
# Downloaded 8600 tweets
# Downloaded 8700 tweets
# Downloaded 8800 tweets
# Downloaded 8900 tweets
# Downloaded 9000 tweets
# Downloaded 9100 tweets
# Downloaded 9200 tweets
# Downloaded 9300 tweets
# Downloaded 9400 tweets
# Downloaded 9500 tweets
# Downloaded 9600 tweets
# Downloaded 9700 tweets
# Downloaded 9800 tweets
# Downloaded 9900 tweets
# Downloaded 10000 tweets
# Downloaded 10100 tweets
# Downloaded 10200 tweets
# Downloaded 10300 tweets
# Downloaded 10400 tweets
# Downloaded 10500 tweets
# Downloaded 10600 tweets
# Downloaded 10700 tweets
# Downloaded 10800 tweets
# Downloaded 10900 tweets
# Downloaded 11000 tweets
# Downloaded 11100 tweets
# Downloaded 11200 tweets
# Downloaded 11300 tweets
# Downloaded 11400 tweets
# Downloaded 11500 tweets
# Downloaded 11600 tweets
# Downloaded 11700 tweets
# Downloaded 11800 tweets
# Downloaded 11900 tweets
# Downloaded 12000 tweets
# Downloaded 12100 tweets
# Downloaded 12200 tweets
# Downloaded 12300 tweets
# Downloaded 12400 tweets
# Downloaded 12500 tweets
# Downloaded 12600 tweets
# Downloaded 12700 tweets
# Downloaded 12800 tweets
# Downloaded 12900 tweets
# Downloaded 13000 tweets
# Downloaded 13100 tweets
# Downloaded 13200 tweets
# Downloaded 13300 tweets
# Downloaded 13400 tweets
# Downloaded 13500 tweets
# Downloaded 13600 tweets
# Downloaded 13700 tweets
# Downloaded 13800 tweets
# Downloaded 13900 tweets
# Downloaded 14000 tweets
# Downloaded 14100 tweets
# Downloaded 14200 tweets
# Downloaded 14300 tweets
# Downloaded 14400 tweets
# Downloaded 14500 tweets
# Downloaded 14600 tweets
# Downloaded 14700 tweets
# Downloaded 14800 tweets
# Downloaded 14900 tweets
# Downloaded 15000 tweets

# %%
tweets2 = get_tweets(num_queries=300, cur_id=tweets[-1].id)
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 400 tweets
# Downloaded 500 tweets
# Downloaded 600 tweets
# Downloaded 700 tweets
# Downloaded 800 tweets
# Downloaded 900 tweets
# Downloaded 1000 tweets
# Downloaded 1100 tweets
# Downloaded 1200 tweets
# Downloaded 1300 tweets
# Downloaded 1400 tweets
# Downloaded 1500 tweets
# Downloaded 1600 tweets
# Downloaded 1700 tweets
# Downloaded 1800 tweets
# Downloaded 1900 tweets
# Downloaded 2000 tweets
# Downloaded 2100 tweets
# Downloaded 2200 tweets
# Downloaded 2300 tweets
# Downloaded 2400 tweets
# Downloaded 2500 tweets
# Downloaded 2600 tweets
# Downloaded 2700 tweets
# Downloaded 2798 tweets
# Downloaded 2898 tweets
# Downloaded 2998 tweets
# Downloaded 3098 tweets
# Downloaded 3198 tweets
# Downloaded 3298 tweets
# Downloaded 3398 tweets
# Downloaded 3498 tweets
# Downloaded 3598 tweets
# Downloaded 3698 tweets
# Downloaded 3798 tweets
# Downloaded 3898 tweets
# Downloaded 3998 tweets
# Downloaded 4098 tweets
# Downloaded 4198 tweets
# Downloaded 4298 tweets
# Downloaded 4398 tweets
# Downloaded 4498 tweets
# Downloaded 4598 tweets
# Downloaded 4698 tweets
# Downloaded 4798 tweets
# Downloaded 4898 tweets
# Downloaded 4998 tweets
# Downloaded 5098 tweets
# Downloaded 5198 tweets
# Downloaded 5298 tweets
# Downloaded 5398 tweets
# Downloaded 5498 tweets
# Downloaded 5598 tweets
# Downloaded 5698 tweets
# Downloaded 5798 tweets
# Downloaded 5898 tweets
# Downloaded 5998 tweets
# Downloaded 6098 tweets
# Downloaded 6198 tweets
# Downloaded 6298 tweets
# Downloaded 6398 tweets
# Downloaded 6498 tweets
# Downloaded 6598 tweets
# Downloaded 6698 tweets
# Downloaded 6798 tweets
# Downloaded 6898 tweets
# Downloaded 6998 tweets
# Downloaded 7098 tweets
# Downloaded 7198 tweets
# Downloaded 7292 tweets
# Downloaded 7392 tweets
# Downloaded 7492 tweets
# Downloaded 7592 tweets
# Downloaded 7692 tweets
# Downloaded 7792 tweets
# Downloaded 7892 tweets
# Downloaded 7992 tweets
# Downloaded 8092 tweets
# Downloaded 8192 tweets
# Downloaded 8292 tweets
# Downloaded 8392 tweets
# Downloaded 8492 tweets
# Downloaded 8592 tweets
# Downloaded 8692 tweets
# Downloaded 8792 tweets
# Downloaded 8892 tweets
# Downloaded 8992 tweets
# Downloaded 9092 tweets
# Downloaded 9192 tweets
# Downloaded 9292 tweets
# Downloaded 9392 tweets
# Downloaded 9492 tweets
# Downloaded 9592 tweets
# Downloaded 9692 tweets
# Downloaded 9792 tweets
# Downloaded 9892 tweets
# Downloaded 9992 tweets
# Downloaded 10092 tweets
# Downloaded 10192 tweets
# Downloaded 10292 tweets
# Downloaded 10392 tweets
# Downloaded 10492 tweets
# Downloaded 10592 tweets
# Downloaded 10692 tweets
# Downloaded 10792 tweets
# Downloaded 10892 tweets
# Downloaded 10992 tweets
# Downloaded 11092 tweets
# Downloaded 11192 tweets
# Downloaded 11292 tweets
# Downloaded 11392 tweets
# Downloaded 11492 tweets
# Downloaded 11592 tweets
# Downloaded 11692 tweets
# Downloaded 11792 tweets
# Downloaded 11892 tweets
# Downloaded 11992 tweets
# Downloaded 12092 tweets
# Downloaded 12192 tweets
# Downloaded 12292 tweets
# Downloaded 12392 tweets
# Downloaded 12492 tweets
# Downloaded 12592 tweets
# Downloaded 12692 tweets
# Downloaded 12792 tweets
# Downloaded 12892 tweets
# Downloaded 12992 tweets
# Downloaded 13092 tweets
# Downloaded 13192 tweets
# Downloaded 13292 tweets
# Downloaded 13392 tweets
# Downloaded 13492 tweets
# Downloaded 13592 tweets
# Downloaded 13692 tweets
# Downloaded 13792 tweets
# Downloaded 13892 tweets
# Downloaded 13992 tweets
# Downloaded 14092 tweets
# Downloaded 14192 tweets
# Downloaded 14292 tweets
# Downloaded 14392 tweets
# Downloaded 14492 tweets
# Downloaded 14592 tweets
# Downloaded 14692 tweets
# Downloaded 14792 tweets
# Downloaded 14892 tweets
# Downloaded 14992 tweets
# Downloaded 15092 tweets
# Downloaded 15192 tweets
# Downloaded 15292 tweets
# Downloaded 15392 tweets
# Downloaded 15492 tweets
# Downloaded 15592 tweets
# Downloaded 15692 tweets
# Downloaded 15792 tweets
# Downloaded 15892 tweets
# Downloaded 15992 tweets
# Downloaded 16092 tweets
# Downloaded 16192 tweets
# Downloaded 16292 tweets
# Downloaded 16392 tweets
# Downloaded 16492 tweets
# Downloaded 16592 tweets
# Downloaded 16692 tweets
# Downloaded 16792 tweets
# Downloaded 16892 tweets
# Downloaded 16992 tweets
# Downloaded 17092 tweets
# Downloaded 17192 tweets
# Downloaded 17292 tweets
# Downloaded 17392 tweets
# Downloaded 17491 tweets
# Downloaded 17591 tweets
# Downloaded 17690 tweets
# Downloaded 17790 tweets
# Downloaded 17890 tweets
# Downloaded 17990 tweets
# Downloaded 18090 tweets
# Downloaded 18190 tweets
# Downloaded 18290 tweets
# Downloaded 18389 tweets
# Downloaded 18489 tweets
# Downloaded 18587 tweets
# Downloaded 18687 tweets
# Downloaded 18787 tweets
# Downloaded 18887 tweets
# Downloaded 18987 tweets
# Downloaded 19087 tweets
# Downloaded 19187 tweets
# Downloaded 19287 tweets
# Downloaded 19387 tweets
# Downloaded 19487 tweets
# Downloaded 19587 tweets
# Downloaded 19687 tweets
# Downloaded 19787 tweets
# Downloaded 19887 tweets
# Downloaded 19986 tweets
# Downloaded 20086 tweets
# Downloaded 20184 tweets
# Downloaded 20284 tweets
# Downloaded 20384 tweets
# Downloaded 20484 tweets
# Downloaded 20584 tweets
# Downloaded 20684 tweets
# Downloaded 20784 tweets
# Downloaded 20884 tweets
# Downloaded 20984 tweets
# Downloaded 21084 tweets
# Downloaded 21184 tweets
# Downloaded 21284 tweets
# Downloaded 21384 tweets
# Downloaded 21484 tweets
# Downloaded 21584 tweets
# Downloaded 21684 tweets
# Downloaded 21784 tweets
# Downloaded 21884 tweets
# Downloaded 21984 tweets
# Downloaded 22084 tweets
# Downloaded 22184 tweets
# Downloaded 22284 tweets
# Downloaded 22384 tweets
# Downloaded 22484 tweets
# Downloaded 22584 tweets
# Downloaded 22684 tweets
# Downloaded 22784 tweets
# Downloaded 22884 tweets
# Downloaded 22984 tweets
# Downloaded 23084 tweets
# Downloaded 23184 tweets
# Downloaded 23284 tweets
# Downloaded 23384 tweets
# Downloaded 23484 tweets
# Downloaded 23584 tweets
# Downloaded 23684 tweets
# Downloaded 23784 tweets
# Downloaded 23884 tweets
# Downloaded 23984 tweets
# Downloaded 24084 tweets
# Downloaded 24184 tweets
# Downloaded 24284 tweets
# Downloaded 24384 tweets
# Downloaded 24484 tweets
# Downloaded 24584 tweets
# Downloaded 24684 tweets
# Downloaded 24784 tweets
# Downloaded 24884 tweets
# Downloaded 24984 tweets
# Downloaded 25084 tweets
# Downloaded 25180 tweets
# Downloaded 25280 tweets
# Downloaded 25380 tweets
# Downloaded 25480 tweets
# Downloaded 25580 tweets
# Downloaded 25680 tweets
# Downloaded 25780 tweets
# Downloaded 25880 tweets
# Downloaded 25980 tweets
# Downloaded 26080 tweets
# Downloaded 26180 tweets
# Downloaded 26280 tweets
# Downloaded 26380 tweets
# Downloaded 26480 tweets
# Downloaded 26580 tweets
# Downloaded 26680 tweets
# Downloaded 26780 tweets
# Downloaded 26880 tweets
# Downloaded 26980 tweets
# Downloaded 27080 tweets
# Downloaded 27180 tweets
# Downloaded 27280 tweets
# Downloaded 27380 tweets
# Downloaded 27480 tweets
# Downloaded 27580 tweets
# Downloaded 27680 tweets
# Downloaded 27780 tweets
# Downloaded 27880 tweets
# Downloaded 27980 tweets
# Downloaded 28080 tweets
# Downloaded 28180 tweets
# Downloaded 28280 tweets
# Downloaded 28379 tweets
# Downloaded 28479 tweets
# Downloaded 28576 tweets
# Downloaded 28676 tweets
# Downloaded 28776 tweets
# Downloaded 28876 tweets
# Downloaded 28976 tweets
# Downloaded 29076 tweets
# Downloaded 29176 tweets
# Downloaded 29276 tweets
# Downloaded 29375 tweets
# Downloaded 29475 tweets
# Downloaded 29570 tweets
# Downloaded 29666 tweets
# Downloaded 29766 tweets
# Downloaded 29866 tweets
# Downloaded 29966 tweets

# %%
tweets3 = get_tweets(num_queries=300, cur_id=tweets2[-1].id)
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 400 tweets
# Downloaded 500 tweets
# Downloaded 600 tweets
# Downloaded 700 tweets
# Downloaded 800 tweets
# Downloaded 900 tweets
# Downloaded 1000 tweets
# Downloaded 1100 tweets
# Downloaded 1200 tweets
# Downloaded 1300 tweets
# Downloaded 1400 tweets
# Downloaded 1500 tweets
# Downloaded 1600 tweets
# Downloaded 1700 tweets
# Downloaded 1800 tweets
# Downloaded 1900 tweets
# Downloaded 2000 tweets
# Downloaded 2100 tweets
# Downloaded 2200 tweets
# Downloaded 2300 tweets
# Downloaded 2400 tweets
# Downloaded 2500 tweets
# Downloaded 2600 tweets
# Downloaded 2700 tweets
# Downloaded 2800 tweets
# Downloaded 2900 tweets
# Downloaded 3000 tweets
# Downloaded 3100 tweets
# Downloaded 3200 tweets
# Downloaded 3300 tweets
# Downloaded 3400 tweets
# Downloaded 3500 tweets
# Downloaded 3600 tweets
# Downloaded 3700 tweets
# Downloaded 3800 tweets
# Downloaded 3900 tweets
# Downloaded 4000 tweets
# Downloaded 4100 tweets
# Downloaded 4200 tweets
# Downloaded 4300 tweets
# Downloaded 4400 tweets
# Downloaded 4500 tweets
# Downloaded 4600 tweets
# Downloaded 4700 tweets
# Downloaded 4800 tweets
# Downloaded 4900 tweets
# Downloaded 5000 tweets
# Downloaded 5100 tweets
# Downloaded 5200 tweets
# Downloaded 5300 tweets
# Downloaded 5400 tweets
# Downloaded 5500 tweets
# Downloaded 5600 tweets
# Downloaded 5700 tweets
# Downloaded 5800 tweets
# Downloaded 5900 tweets
# Downloaded 6000 tweets
# Downloaded 6100 tweets
# Downloaded 6200 tweets
# Downloaded 6300 tweets
# Downloaded 6400 tweets
# Downloaded 6500 tweets
# Downloaded 6600 tweets
# Downloaded 6700 tweets
# Downloaded 6800 tweets
# Downloaded 6900 tweets
# Downloaded 7000 tweets
# Downloaded 7100 tweets
# Downloaded 7200 tweets
# Downloaded 7300 tweets
# Downloaded 7400 tweets
# Downloaded 7500 tweets
# Downloaded 7600 tweets
# Downloaded 7700 tweets
# Downloaded 7800 tweets
# Downloaded 7900 tweets
# Downloaded 8000 tweets
# Downloaded 8099 tweets
# Downloaded 8199 tweets
# Downloaded 8299 tweets
# Downloaded 8399 tweets
# Downloaded 8499 tweets
# Downloaded 8599 tweets
# Downloaded 8699 tweets
# Downloaded 8799 tweets
# Downloaded 8899 tweets
# Downloaded 8999 tweets
# Downloaded 9099 tweets
# Downloaded 9199 tweets
# Downloaded 9299 tweets
# Downloaded 9398 tweets
# Downloaded 9498 tweets
# Downloaded 9598 tweets
# Downloaded 9698 tweets
# Downloaded 9798 tweets
# Downloaded 9898 tweets
# Downloaded 9998 tweets
# Downloaded 10098 tweets
# Downloaded 10198 tweets
# Downloaded 10298 tweets
# Downloaded 10398 tweets
# Downloaded 10498 tweets
# Downloaded 10598 tweets
# Downloaded 10698 tweets
# Downloaded 10798 tweets
# Downloaded 10898 tweets
# Downloaded 10998 tweets
# Downloaded 11098 tweets
# Downloaded 11198 tweets
# Downloaded 11298 tweets
# Downloaded 11398 tweets
# Downloaded 11498 tweets
# Downloaded 11598 tweets
# Downloaded 11698 tweets
# Downloaded 11798 tweets
# Downloaded 11898 tweets
# Downloaded 11998 tweets
# Downloaded 12098 tweets
# Downloaded 12198 tweets
# Downloaded 12297 tweets
# Downloaded 12397 tweets
# Downloaded 12497 tweets
# Downloaded 12597 tweets
# Downloaded 12697 tweets
# Downloaded 12797 tweets
# Downloaded 12897 tweets
# Downloaded 12997 tweets
# Downloaded 13097 tweets
# Downloaded 13197 tweets
# Downloaded 13297 tweets
# Downloaded 13397 tweets
# Downloaded 13497 tweets
# Downloaded 13597 tweets
# Downloaded 13697 tweets
# Downloaded 13797 tweets
# Downloaded 13897 tweets
# Downloaded 13997 tweets
# Downloaded 14097 tweets
# Downloaded 14197 tweets
# Downloaded 14297 tweets
# Downloaded 14397 tweets
# Downloaded 14497 tweets
# Downloaded 14597 tweets
# Downloaded 14697 tweets
# Downloaded 14797 tweets
# Downloaded 14897 tweets
# Downloaded 14997 tweets
# sleeping for 703.5415577888489 seconds
# Downloaded 15097 tweets
# Downloaded 15197 tweets
# Downloaded 15297 tweets
# Downloaded 15397 tweets
# Downloaded 15497 tweets
# Downloaded 15597 tweets
# Downloaded 15697 tweets
# Downloaded 15797 tweets
# Downloaded 15897 tweets
# Downloaded 15997 tweets
# Downloaded 16097 tweets
# Downloaded 16197 tweets
# Downloaded 16297 tweets
# Downloaded 16397 tweets
# Downloaded 16497 tweets
# Downloaded 16597 tweets
# Downloaded 16697 tweets
# Downloaded 16797 tweets
# Downloaded 16897 tweets
# Downloaded 16997 tweets
# Downloaded 17097 tweets
# Downloaded 17197 tweets
# Downloaded 17297 tweets
# Downloaded 17397 tweets
# Downloaded 17496 tweets
# Downloaded 17596 tweets
# Downloaded 17696 tweets
# Downloaded 17796 tweets
# Downloaded 17896 tweets
# Downloaded 17996 tweets
# Downloaded 18096 tweets
# Downloaded 18196 tweets
# Downloaded 18294 tweets
# Downloaded 18380 tweets
# Downloaded 18472 tweets
# Downloaded 18544 tweets
# Downloaded 18626 tweets
# Downloaded 18700 tweets
# Downloaded 18779 tweets
# Downloaded 18859 tweets
# Downloaded 18940 tweets
# Downloaded 19032 tweets
# Downloaded 19132 tweets
# Downloaded 19232 tweets
# Downloaded 19332 tweets
# Downloaded 19432 tweets
# Downloaded 19532 tweets
# Downloaded 19632 tweets
# Downloaded 19732 tweets
# Downloaded 19832 tweets
# Downloaded 19932 tweets
# Downloaded 20032 tweets
# Downloaded 20132 tweets
# Downloaded 20232 tweets
# Downloaded 20332 tweets
# Downloaded 20432 tweets
# Downloaded 20532 tweets
# Downloaded 20632 tweets
# Downloaded 20732 tweets
# Downloaded 20832 tweets
# Downloaded 20932 tweets
# Downloaded 21032 tweets
# Downloaded 21132 tweets
# Downloaded 21232 tweets
# Downloaded 21332 tweets
# Downloaded 21432 tweets
# Downloaded 21532 tweets
# Downloaded 21632 tweets
# Downloaded 21732 tweets
# Downloaded 21832 tweets
# Downloaded 21932 tweets
# Downloaded 22032 tweets
# Downloaded 22132 tweets
# Downloaded 22232 tweets
# Downloaded 22332 tweets
# Downloaded 22432 tweets
# Downloaded 22532 tweets
# Downloaded 22632 tweets
# Downloaded 22718 tweets
# Downloaded 22818 tweets
# Downloaded 22914 tweets
# Downloaded 23009 tweets
# Downloaded 23106 tweets
# Downloaded 23206 tweets
# Downloaded 23306 tweets
# Downloaded 23405 tweets
# Downloaded 23505 tweets
# Downloaded 23599 tweets
# Downloaded 23699 tweets
# Downloaded 23799 tweets
# Downloaded 23890 tweets
# Downloaded 23990 tweets
# Downloaded 24090 tweets
# Downloaded 24190 tweets
# Downloaded 24290 tweets
# Downloaded 24390 tweets
# Downloaded 24490 tweets
# Downloaded 24590 tweets
# Downloaded 24690 tweets
# Downloaded 24790 tweets
# Downloaded 24890 tweets
# Downloaded 24990 tweets
# Downloaded 25090 tweets
# Downloaded 25190 tweets
# Downloaded 25290 tweets
# Downloaded 25390 tweets
# Downloaded 25490 tweets
# Downloaded 25590 tweets
# Downloaded 25690 tweets
# Downloaded 25790 tweets
# Downloaded 25890 tweets
# Downloaded 25990 tweets
# Downloaded 26090 tweets
# Downloaded 26190 tweets
# Downloaded 26290 tweets
# Downloaded 26390 tweets
# Downloaded 26490 tweets
# Downloaded 26590 tweets
# Downloaded 26690 tweets
# Downloaded 26790 tweets
# Downloaded 26890 tweets
# Downloaded 26990 tweets
# Downloaded 27090 tweets
# Downloaded 27190 tweets
# Downloaded 27290 tweets
# Downloaded 27390 tweets
# Downloaded 27490 tweets
# Downloaded 27590 tweets
# Downloaded 27690 tweets
# Downloaded 27790 tweets
# Downloaded 27890 tweets
# Downloaded 27990 tweets
# Downloaded 28090 tweets
# Downloaded 28190 tweets
# Downloaded 28290 tweets
# Downloaded 28390 tweets
# Downloaded 28490 tweets
# Downloaded 28590 tweets
# Downloaded 28690 tweets
# Downloaded 28790 tweets
# Downloaded 28890 tweets
# Downloaded 28990 tweets
# Downloaded 29090 tweets
# Downloaded 29190 tweets
# Downloaded 29290 tweets
# Downloaded 29390 tweets
# Downloaded 29490 tweets
# Downloaded 29590 tweets
# Downloaded 29690 tweets
# Downloaded 29790 tweets

# %%
all_tweets = tweets + tweets2 + tweets3

# %%
len(all_tweets)
# Out:
# 74756

# %% [markdown]
# ### Make dataset

# %%
import pandas as pd

# %%
dicts = [dict(tweet) for tweet in all_tweets]

# %%
df = pd.DataFrame(dicts)

# %%
df.head()
# Out:
#          author  comments                            date                  id  \
# 0       TeddMcc         0  Thu May 17 17:15:19 +0000 2018  997163668386136065
# 1  AtheisticLib         0  Thu May 17 17:15:19 +0000 2018  997163668319096832
# 2   tmaysshuman         0  Thu May 17 17:15:19 +0000 2018  997163667211812865
# 3   wgriffin4th         0  Thu May 17 17:15:17 +0000 2018  997163657988632577
# 4    lance_pool         0  Thu May 17 17:15:16 +0000 2018  997163656440958976
#
#   language                                            profile  shares  \
# 0      und  http://pbs.twimg.com/profile_images/9098076945...       1
# 1       en  http://pbs.twimg.com/profile_images/9666263670...       0
# 2       en  http://pbs.twimg.com/profile_images/9527432988...     208
# 3       en  http://pbs.twimg.com/profile_images/8300480829...       0
# 4       en  http://abs.twimg.com/sticky/default_profile_im...    4656
#
#                                                 text title  \
# 0  RT @ChrissyUSA1: #MAGA #Patriot #Qanon #WeTheP...
# 1  @FoxNews @WhiteHouse Coming up on the next epi...
# 2  RT @RealDonaldTrFan: Unlike LOSER Obama, under...
# 3  Democrats - the party of anarchy. Sad #maga @D...
# 4  RT @GayRepublicSwag: I have a friend who voted...
#
#                                                  url  votes
# 0  https://twitter.com/TeddMcc/status/99716366838...      0
# 1  https://twitter.com/AtheisticLib/status/997163...      0
# 2  https://twitter.com/tmaysshuman/status/9971636...      0
# 3  https://twitter.com/wgriffin4th/status/9971636...      0
# 4  https://twitter.com/lance_pool/status/99716365...      0

# %%
dict(all_tweets[0])
# Out:
# {'url': 'https://twitter.com/TeddMcc/status/997163668386136065',
#  'id': '997163668386136065',
#  'title': '',
#  'text': 'RT @ChrissyUSA1: #MAGA #Patriot #Qanon #WeThePeople #TheStormIsHere #GodIsInCharge #JesusLives #InternetBillOfRights #No2Censorship #Free2Think #VoteRed #RedWaveRising https://t.co/iuymU4FGeJ',
#  'language': 'und',
#  'author': 'TeddMcc',
#  'date': 'Thu May 17 17:15:19 +0000 2018',
#  'votes': 0,
#  'shares': 1,
#  'comments': 0,
#  'profile': 'http://pbs.twimg.com/profile_images/909807694558633984/ldj7XMQL_normal.jpg'}

# %%
df.to_csv("maga_tweets.csv")
